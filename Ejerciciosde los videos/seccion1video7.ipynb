# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Carga y manipulación

# %%
df = pd.read_csv(r'C:\Users\carlo\Documents\Data Science con python-Numpy y pandas\Recursos del curso\Datasets+Data+Science+con+Python+-+Pandas\1.3\Info_pais.csv',encoding = "ISO-8859-1", delimiter=";")

# %%
df_order = df.sort_values("Esperanza de vida", ascending=True)

# %%
df_order.head()
# Out:
#                          País  Poblacion  Renta per capita Esperanza de vida
# 151  Central African Republic    4596023               424              52,8
# 149                   Lesotho    2091534              1233              53,7
# 128                      Chad   15016753               657                54
# 143              Sierra Leone    7488423               504              54,3
# 28                    Nigeria  190873244              1969              54,3

# %% [markdown]
# Visualizacion

# %%
plt.scatter(df_order["Renta per capita"],df_order["Esperanza de vida"])
plt.title("Renta per capita vs Esperanza de vida")
plt.xlabel("Renta per capita")
plt.ylabel("Esperanza de vida")
# Out:
# Text(0, 0.5, 'Esperanza de vida')

# %%
df_order["Pobl_norm"]= df_order["Poblacion"]/(max(df_order["Poblacion"])/10000)

# %%
df_order.head()
# Out:
#                          País  Poblacion  Renta per capita Esperanza de vida  \
# 151  Central African Republic    4596023               424              52,8
# 149                   Lesotho    2091534              1233              53,7
# 128                      Chad   15016753               657                54
# 143              Sierra Leone    7488423               504              54,3
# 28                    Nigeria  190873244              1969              54,3
#
#        Pobl_norm
# 151    32.343086
# 149    14.718522
# 128   105.675740
# 143    52.697454
# 28   1343.211239

# %%
plt.scatter(df_order["Renta per capita"],df_order["Esperanza de vida"], s=df_order["Pobl_norm"], c=df_order["Pobl_norm"])
plt.title("Renta per capita vs Esperanza de vida")
plt.xlabel("Renta per capita")
plt.ylabel("Esperanza de vida")

fig = plt.gcf()
fig.set_size_inches(14.5, 10)

for i in range(1,10):
    plt.annotate(df_order["País"][i], (df_order["Renta per capita"][i], df_order["Esperanza de vida"][i]))
plt.yticks(ticks=range(1,120,10))
# Out:
# ([<matplotlib.axis.YTick at 0x219d551f150>,
#   <matplotlib.axis.YTick at 0x219d550a350>,
#   <matplotlib.axis.YTick at 0x219d550d590>,
#   <matplotlib.axis.YTick at 0x219d5557290>,
#   <matplotlib.axis.YTick at 0x219d5559310>,
#   <matplotlib.axis.YTick at 0x219d555a7d0>,
#   <matplotlib.axis.YTick at 0x219d555ca50>,
#   <matplotlib.axis.YTick at 0x219d555ec10>,
#   <matplotlib.axis.YTick at 0x219d5564d10>,
#   <matplotlib.axis.YTick at 0x219d5566c90>,
#   <matplotlib.axis.YTick at 0x219d5557c90>,
#   <matplotlib.axis.YTick at 0x219d5571190>],
#  [Text(0, 1, '53,7'),
#   Text(0, 11, '61,2'),
#   Text(0, 21, '63,9'),
#   Text(0, 31, '66,9'),
#   Text(0, 41, '69,7'),
#   Text(0, 51, '71,6'),
#   Text(0, 61, '73,3'),
#   Text(0, 71, '74,6'),
#   Text(0, 81, '76,1'),
#   Text(0, 91, '77,6'),
#   Text(0, 101, '81,2'),
#   Text(0, 111, '82,7')])
