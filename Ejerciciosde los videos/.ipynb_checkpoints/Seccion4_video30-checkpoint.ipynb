# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
Eje = np.random.normal(3, 1.5, 10000)

# %%
#percen=np.percentile(Eje,95)

# %%
mediana=np.mean(Eje)
Desvia=np.std(Eje)

# %%
Rango_95=[mediana-2*Desvia,mediana+2*Desvia]

# %%
Rango_95
# Out:
# [-0.022612680388576223, 5.999048706164574]

# %%
plt.scatter(Eje, stats.norm.pdf(Eje, mediana, Desvia))
